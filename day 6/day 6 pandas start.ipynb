# %%
#what is data
#Data is raw, unorganized facts and figures that can be processed by a computer
#to gain insights and knowledge.

# %%
# what is a data set?
# data set is made of column rows indexes and variables
# variables are columns

# %%
#data science steps
#data collection
# what is primary data ?
#primary data is orignal data you created
#what is secondary data?
#logo ka data is simply secondary data

# %%
# what is data science ?
# simple and straighforward definition of it will be
# data ka andar chupay howa raaz nikalna is simply data science
#data science is about using data to answer questions, solve problems, and make
#better decisions

# %%
#Secondary data sources ?
#kaggle ,google data search,github,faostats.com,wikipedia,twitter,fb(data scrapping )
#buissiness analytics data ,stock exchange data ,NADRA data ,University data bases
#research data bases

# %%
pip install pandas numpy matplotlib seaborn sklearn
# Out:
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel("/pandas_01_day6.xlsx")
df
# Out:
#     Height  Weight Favourite Dish
# 0      5.8     101  Chicken Pulao
# 1      6.2      92        Biryani
# 2      5.9      62  Karahi Ghosht
# 3      5.9      95  Chicken Pulao
# 4      5.9      55  Chicken Pulao
# ..     ...     ...            ...
# 82     5.4      55          Pasta
# 83     5.9      75  Karahi Ghosht
# 84     5.4      61        Biryani
# 85     6.2      68  Chicken Pulao
# 86     5.1      96        Biryani
#
# [87 rows x 3 columns]

# %%
df.head()
# Out:
#    Height  Weight Favourite Dish
# 0     5.8     101  Chicken Pulao
# 1     6.2      92        Biryani
# 2     5.9      62  Karahi Ghosht
# 3     5.9      95  Chicken Pulao
# 4     5.9      55  Chicken Pulao

# %%
df.tail()
# Out:
#     Height  Weight Favourite Dish
# 82     5.4      55          Pasta
# 83     5.9      75  Karahi Ghosht
# 84     5.4      61        Biryani
# 85     6.2      68  Chicken Pulao
# 86     5.1      96        Biryani

# %%
df.shape
# Out:
# (87, 3)

# %%
df.head(10)
# Out:
#    Height  Weight Favourite Dish
# 0     5.8     101  Chicken Pulao
# 1     6.2      92        Biryani
# 2     5.9      62  Karahi Ghosht
# 3     5.9      95  Chicken Pulao
# 4     5.9      55  Chicken Pulao
# 5     5.3      59        Biryani
# 6     5.6      50          Pasta
# 7     5.9      76        Biryani
# 8     5.1      78        Biryani
# 9     5.4      68        Biryani

# %%
df.tail(10)
# Out:
#     Height  Weight Favourite Dish
# 77    5.50      85        Biryani
# 78    5.11      72  Karahi Ghosht
# 79    5.30      62        Biryani
# 80    5.40      55          Pasta
# 81    5.50      52  Karahi Ghosht
# 82    5.40      55          Pasta
# 83    5.90      75  Karahi Ghosht
# 84    5.40      61        Biryani
# 85    6.20      68  Chicken Pulao
# 86    5.10      96        Biryani

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Height          87 non-null     float64
#  1   Weight          87 non-null     int64
#  2   Favourite Dish  87 non-null     object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.2+ KB

# %%
df.index
# Out:
# RangeIndex(start=0, stop=87, step=1)

# %%
df.columns
# Out:
# Index(['Height', 'Weight', 'Favourite Dish'], dtype='object')

# %%
df.describe()
# Out:
#            Height      Weight
# count   87.000000   87.000000
# mean     9.998391   70.459770
# std     25.733340   16.753899
# min      5.000000   25.000000
# 25%      5.300000   60.000000
# 50%      5.600000   70.000000
# 75%      5.850000   80.000000
# max    178.000000  125.000000

# %%
df.sort_index(ascending=False)
# Out:
#     Height  Weight Favourite Dish
# 86     5.1      96        Biryani
# 85     6.2      68  Chicken Pulao
# 84     5.4      61        Biryani
# 83     5.9      75  Karahi Ghosht
# 82     5.4      55          Pasta
# ..     ...     ...            ...
# 4      5.9      55  Chicken Pulao
# 3      5.9      95  Chicken Pulao
# 2      5.9      62  Karahi Ghosht
# 1      6.2      92        Biryani
# 0      5.8     101  Chicken Pulao
#
# [87 rows x 3 columns]
